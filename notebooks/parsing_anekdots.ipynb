# %%
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$         INITIAL SETTINGS - НАЧАЛЬНЫЕ УСТАНОВКИ          $$$$$$$$$$$$$$$$$$$$$$$$$$$$

# %%
# Pandas
import pandas as pd
import numpy as np
import sys

# Подключаем библиотеку для парсинга сайтов !!!!!!!!!!!!!
import requests

# Подключаем библиотеку для поиска элементов кода на сайте !!!!!!!!!!!!!
from bs4 import BeautifulSoup

# %%
# 
# import sys

# %%
# Установка библиотеки для парсинга сайтов !!!!!!!!!!!!!
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\anaconda3\lib\site-packages (from requests) (2.10)

# %%
# Подключаем библиотеку для парсинга сайтов !!!!!!!!!!!!!
import requests

# %%
# Отправка запроса на сайт для получения кода:
res = requests.get('https://www.landy-art.ru/additional/humor/best_stories.html')
res.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head lang="ru-RU">\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n<title>Лучшие анекдоты  - Юмор - Дополнительно - Landy-Art.ru</title>\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta http-equiv="cleartype" content="yes">\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n<link type="text/css" href="/style.css?v=1648980843" rel="stylesheet">\n<!--[if lt IE 9]>\n<script src="/frontend/html5shiv.min.js"></script>\n<![endif]-->\n        <script type="text/javascript" src="/frontend/js/jquery.js"></script>\n<meta name="keywords" content="">\n<meta name="description" content="">\n        <script type="text/javascript">\n        var _gaq = _gaq || [];\n        _gaq.push([\'_setAccount\', \'UA-16752262-20\']);\n        _gaq.push([\'_trackPageview\']);\n        (function() {\n        var ga = document.createElement(\'script\'); ga.type = \'text/javascript\'; ga.async = true;\n        ga.src = (\'https:\' == document.location.protocol ? \'https://ssl\' : \'https://www\') + \'.google-analytics.com/ga.js\';\n        var s = document.getElementsByTagName(\'script\')[0]; s.parentNode.insertBefore(ga, s);\n        })();\n        </script>\n        <script type="text/javascript" src="/js/resize.js"></script>\n<script type="text/javascript" src="https://vk.com/js/api/openapi.js?168"></script>\n</head>\n<body>\n        <div id="fb-root"></div>\n        <div class="mobile">\n            <a href="#" class="mobile-close" data-function="toggle-mobile-menu"></a>\n    <a href="/company/about_us.html" class="mobile-nav-item">О нас</a>\n    <a href="/company/tseny.html" class="mobile-nav-item">Цены</a>\n    <a href="/company/partners/index.html" class="mobile-nav-item">Партнеры</a>\n    <a href="/company/reviews/index.html" class="mobile-nav-item">Отзывы</a>\n    <a href="/company/contacts.html" class="mobile-nav-item">Контакты</a>\n    <a href="/cabinet/index.html" class="mobile-nav-item">Личный кабинет</a>\n    <a href="/helpful_information/catalogue_of_plants.html" class="mobile-nav-item">Каталог растений</a>\n    <a href="/helpful_information/publications/index.html" class="mobile-nav-item">Публикации</a>\n    <a href="/helpful_information/garden_parks.html" class="mobile-nav-item">Сады и парки</a>\n    <a href="/helpful_information/our_cd_books.html" class="mobile-nav-item">Интернет-магазин</a>\n    <a href="/helpful_information/news.html" class="mobile-nav-item">Новости</a>\n    <a href="/helpful_information/nashi-filmi.html" class="mobile-nav-item">Наши фильмы</a>\n    <a href="/company/proekti.html" class="mobile-nav-item">Проекты</a>\n    <a href="/company/photogalery.html" class="mobile-nav-item">Портфолио</a>\n        </div>\n        <a href="#" class="open-mobile" data-function="toggle-mobile-menu"></a>\n<div class="wrapper">\n            <header class="header">\n                <div class="main-inner">\n                    <div class="header-top row">\n                        <div class="col-3-12 col-6-12-md col-12-12-sm">\n                            <a href="/" class="logo"></a>\n                        </div>\n                        <div class="col-4-12 col-6-12-md col-12-12-xs">\n                            <div class="header-phone">\n                                <a href="tel:+79255177660">+7 (925) 517 76 60</a>\n                            </div>\n                        </div>\n                        <div class="col-5-12 col-12-12-md col-6-12-sm col-12-12-xs">\n                            <div class="topmenu">\n            <a href="/company/about_us.html" class="topmenu-item">О нас</a>\n            <a href="/company/tseny.html" class="topmenu-item">Цены</a>\n            <a href="/company/partners/index.html" class="topmenu-item">Партнеры</a>\n            <a href="/company/reviews/index.html" class="topmenu-item">Отзывы</a>\n            <a href="/company/contacts.html" class="topmenu-item">Контакты</a>\n            <a href="/cabinet/index.html" ...

# %%
# Искать нужные элементы в коде с помощью библиотеки:
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\anaconda3\lib\site-packages (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in c:\anaconda3\lib\site-packages (from beautifulsoup4) (2.0.1)

# %%
# Подключаем библиотеку для поиска элементов кода на сайте !!!!!!!!!!!!!
from bs4 import BeautifulSoup

# %%
# Magic
soup = BeautifulSoup(res.text, 'html')
links = soup.find_all('p')
links
# Out:
# [<p class="h-text-error">Нет товаров</p>,
#  <p class="h-text-center"><button class="btn" data-remodal-action="close" type="button">Продолжить покупки</button></p>,
#  <p>В  Москве проходит тендер на строительство здания. Проект представляет  немецкая компания. Смета 10 миллионов. Затем турецкая компания – 5  миллионов. Подходит черед российской компании. У них смета 15 миллионов.</p>,
#  <p>- Почему так много?</p>,
#  <p>- Ну, как же? 5 миллионов нам,  5 миллионов вам и 5 туркам, чтобы строили.</p>,
#  <p>И они выигрывают тендер!</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Один бизнесмен хотел жениться,  но у него было три подружки, и он не знал какую из них выбрать. Решил  их проверить: дал каждой по 1000 долларов. Одна потратила все деньги на  себя, другая купила что-то для хозяйства, а третья вложила в дело и  получила прибыль. Какую же из трех он выбрал? Ту, у которой грудь  больше!</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Едет русский на своем  автомобиле по Украине. Его останавливает украинский гаишник:</p>,
#  <p>- Вы нарушили правила, пишите  объяснительную записку на украинском языке.</p>,
#  <p>- Но я не умею, на  украинском!..</p>,
#  <p>- Тогда отберем права.</p>,
#  <p>Что делать? Русский положил в  чистый лист 100 долларов. Гаишник смотрит.</p>,
#  <p>-Ну, вот, говорите, что не  умеете, а половину уже написали!</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Поздний вечер. Мужа нет дома.  Жена волнуется.</p>,
#  <p>- Наверное, он с другой  женщиной, я давно подозревала…</p>,
#  <p>Теща:</p>,
#  <p>- Зачем ты думаешь сразу о  плохом? Может быть, он просто попал под машину…</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Женщины бывают или «прелесть,  какие глупенькие», или «ужас, какие дуры!»</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Урок в кавказской школе. Учитель  вызвал ученика и попросил начертить равнобедренный треугольник. Мальчик  начертил. Учитель:</p>,
#  <p>- А теперь докажи, что он  равнобедренный.</p>,
#  <p>- Мамой клянусь, равнобедренный!</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Объявлен  международный тендер на прокладку трубопровода по дну океана из Европы в  Америку. Проект представляет немецкая компания, показывает графики,  схемы, сметы.</p>,
#  <p>- Мы будем  работать три года. Начнем с двух сторон. Когда дойдем до середины,  гарантируем, что расхождение будет не более десяти метров.</p>,
#  <p>Японская  компания, показывает проект:</p>,
#  <p>- Мы будем  работать два года. Начнем с двух сторон. Когда дойдем до середины,  гарантируем, что расхождение будет не более пяти метров.</p>,
#  <p>Русская  компания:</p>,
#  <p>- Мы будем  работать полгода. Начнем с двух сторон. Ничего не гарантируем. В крайнем  случае, будет две трубы.</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Солдат  спрашивает у прапорщика:</p>,
#  <p>- Товарищ  прапорщик, а крокодилы летают?</p>,
#  <p>- Конечно,  нет! Ерунда какая!</p>,
#  <p>- Да?.. А  товарищ лейтенант сказал, что летают…</p>,
#  <p>- Ну, они  летают, но только низенько-низенько.</p>,
#  <p>- А товарищ  лейтенант сказал, что высоко.</p>,
#  <p>- Они  сначала низенько-низенько, а потом как взмоют!</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Разговаривают  два солдатика.</p>,
#  <p>- Слушай,  давай над лейтенантом приколемся.</p>,
#  <p>- Ага, над деканом уже  прикололись…</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Штирлиц  проснулся в камере. Как сюда попал, не помнит. Думает: «Если войдут  русские, скажу, что я полковник Исаев. Если немцы – штандартенфюрер  Штирлиц».</p>,
#  <p>Входит  милиционер:</p>,
#  <p>-Ну, и  напились Вы вчера, товарищ Тихонов!</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Москвичей  нигде не любят, особенно в Москве…</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Белорусские  новости: «Александр Григорьевич Лукашенко заявил, что он не хочет больше  быть президентом. Коронация назначена на вторник».</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>У одного  мужика была бахча, но кто-то повадился таскать с нее арбузы. Чтобы это  прекратить, он поставил табличку «Внимание! Один из арбузов отравлен».  На следующий день видит, на табличке подписано: «Теперь их два…»</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Китаец был в  Москве. Когда вернулся домой, родственники его спрашивают:</p>,
#  <p>-Ну, как  тебе Москва?</p>,
#  <p>-Хороший  город, чистый и народу мало!</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Богатый  студент пришел на экзамен, но не подготовился. Положил в чистую тетрадь  пять тысяч долларов и написал: «Профессор, по штуке за балл». Когда ему  вернули тетрадь с результатами, там лежало три тысячи и рукой профессора  написано: «Сдача».</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Из ПДД для  блондинок: «Действие знака «Обгон запрещен» распространяется не только  на автомобили красного цвета».</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Один  строитель всю жизнь строил мосты, а когда ушел на пенсию, его дело  продолжил сын. Однажды сын пришел к отцу и с гордостью говорит:</p>,
#  <p>-  Папа, я достроил мост, который ты строил тридцать лет!</p>,
#  <p>-  Сынок, пока строился этот мост, я тебя вырастил и выучил. А ты как  будешь кормить свою семью?</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Разговор  двух приятелей:</p>,
#  <p>- Я  свою жену называю «зайка», «рыбка», «птичка»…</p>,
#  <p>-  Ну, а она что?</p>,
#  <p>-  Уши развесит, глаза выпучит и клювом щелкает!</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Что такое рай? Это английский  дом, китайская кухня, американская зарплата и русская жена.</p>,
#  <p>А что такое ад? Это китайский  дом, английская кухня, русская зарплата и американская жена.</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Если  мужчине сказать: «Ты такой же дурак, как Вася!» Он спросит, почему это  он дурак?</p>,
#  <p>Если  женщине сказать: «Ты такая же дура, как Маша!» Она возмутится: Почему  это я, как Маша?!»</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>МУЖСКОЙ РЕЦЕПТ  ШАРЛОТКИ (простого яблочного пирога).</p>,
#  <p>Возьмите  из холодильника 10 яиц, положите на стол оставшиеся семь и вытрите пол.  Возьмите большую миску и разбейте об ее край яйца. Вылейте их  содержимое в миску. Протрите стол. Итак, у вас в миске 5 яиц. Теперь  возьмите миксер, вставьте венчики и начните взбивать. Попробуйте еще раз  вставить венчики, теперь до щелчка. Взбивайте. Вымойте лицо, шею, руки,  спину, уши. В итоге у вас в миске осталось два взбитых яйца. Обклейте  стены и потолок кухни газетой, накройте мебель какой-нибудь тканью –  пора доставать муку… Насыпьте 200 г в стакан, затем высыпьте в миску.  Оставшиеся 800 г аккуратно соберите обратно в пакет. Взбивайте. Примите  душ. Возьмите 4 больших яблока и нож. Приготовьте йод, пластырь и бинт.  Очистите яблоки. Обработайте большой палец йодом и забинтуйте его.  Нарежьте яблоки кубиками и помните, вам понадобится 2 яблока, так что в  процессе готовки можно съесть только половину. Обработайте йодом  указательный и средний пальцы. Единственное оставшееся и уже нарезанное  яблоко сбросьте в миску, подберите с пола упавшие кусочки, помойте их и  тоже положите в миску. Взбивайте все миксером. Отмойте холодильник.  Теперь выливайте содержимое в сковородку и ставьте в духовку. Подождите  час и, не увидев ощутимых изменений, включите духовку. Проснувшись, не  звоните в Службу спасения, а просто выключите духовку и откройте окна...</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Объявление в  газете: «Потомственный алкоголик в четвертом поколении быстро и  безболезненно снимет любую кодировку».</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Разговор двух подростков:</p>,
#  <p>- Мне отец привез из Африки  большого попугая за тысячу долларов!</p>,
#  <p>- Красивый попугай?</p>,
#  <p>- Красивый!</p>,
#  <p>- Говорящий?</p>,
#  <p>- Говорящий!</p>,
#  <p>- Вкусный?</p>,
#  <p>- Ты что?! Попугай штуку  баксов стоит. Конечно, вкусный!</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>- Сынок, с 23-им февраля!</p>,
#  <p>- Пап, не каркай, может, я еще  поступлю…</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>- У меня на даче дом-на.</p>,
#  <p>- Зачем тебе?</p>,
#  <p>- Я там живу-на!</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>- Будет ли Третья мировая  ойна?</p>,
#  <p>- Будет.</p>,
#  <p>- А сколько после войны будет  стоить в Америке банка «Кока-колы»?</p>,
#  <p>- Один рубль.</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Студент духовной семинарии  полюбил дочку олигарха. Он решили пожениться. Пришел жених поговорить с  отцом невесты.</p>,
#  <p>- А Вы знаете, что моя дочь  привыкла ни в чем себе не отказывать? Она шубы и драгоценности через  день покупает. Вы сможете ей это обеспечить?</p>,
#  <p>- Боженька поможет!</p>,
#  <p>- А еще она дорогие машины  меняет по нескольку раз в год.</p>,
#  <p>- Боженька поможет!</p>,
#  <p>- Она еще часто за границу  ездит, на отдых, на шопинг…</p>,
#  <p>- Боженька поможет!</p>,
#  <p>Позже дочка спрашивает:</p>,
#  <p>- Папа, тебе понравился мой  жених?</p>,
#  <p>- Он, конечно, полный ноль, но  приятно, что меня боженькой называет…</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Адам спрашивает у Бога:</p>,
#  <p>- Господи, почему ты сделал  Еву такой красивой?</p>,
#  <p>- Чтобы она тебе понравилась,  сын мой.</p>,
#  <p>- Боже, но почему же ты сделал  ее такой глупой?</p>,
#  <p>- А это, чтобы ты ей  понравился…</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Приехали в Новую Зеландию три  приятеля – биолог, физик и математик. Едут на машине. Видят, на зеленом  лугу пасется черная овца.</p>,
#  <p>Биолог: Это говорит о том, что  здесь водятся черные овцы.</p>,
#  <p>Физик: Это говорит о том, что  здесь водится по крайней мере одна черная овца.</p>,
#  <p>Математик: Это говорит о том,  здесь водится по крайней мере одна овца, черная по крайней мере с одной  стороны.</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Пошли муж и жена на охоту. Он  дал ей ружье.</p>,
#  <p>- Я на тебя из леса выгоню  лося, и ты тогда стреляй.</p>,
#  <p>Ушел в лес. Вдруг слышит  выстрелы, шум, крики. Подбегает, а там его жена и какой-то мужик. Жена  наставила на него ружье и кричит:</p>,
#  <p>- Это мой лось! Отойди!</p>,
#  <p>- Ладно-ладно, твой. Можно, я  только седло сниму?</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Подходит  школе  к Вовочке девочка:</p>,
#  <p>- Вовочка, у вас дома ТАКОЕ!</p>,
#  <p>Потом подошел и директор  школы:</p>,
#  <p>- Вовочка, иди домой, у вас  дома ТАКОЕ!</p>,
#  <p>На улице знакомые тоже  говорили:</p>,
#  <p>- Вовочка, у вас дома ТАКОЕ!</p>,
#  <p>Прибежал он домой. И ему  говорят:</p>,
#  <p>- Вовочка, у нас ТАКОЕ! Твой  брат Саша бомбу в царя бросил…</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Немец в Лондоне заходит в паб:</p>,
#  <p>- Two Martini,  please.</p>,
#  <p>- Dry?</p>,
#  <p>- Nein, nur zwei!</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>В зоопарке  медведь жалуется директору:</p>,
#  <p>- Переведите меня в другую  клетку, я так больше жить не могу! У меня справа обезьяна, а слева  жираф. Обезьяна весь день анекдоты рассказывает, а жираф всю ночь  смеется.</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Два электрика в подъезде  что-то чинят и спорят. Идет бабушка.</p>,
#  <p>- Бабушка! Подержи провод.</p>,
#  <p>- Ну, вот, я же тебе говорил,  что это ноль, а ты «фаза-фаза»…</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>- Правильно говорят, что  блондинки глупые! Моя жена была брюнеткой, вчера днем перекрасилась в  блондинку, а вечером устроила скандал, когда нашла в постели черные  волосы.</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Собака думает: Человек обо мне  заботится, кормит меня, поит, дает кров. Наверное, он Бог!</p>,
#  <p>Кошка думает: Человек обо мне  заботится, кормит меня, поит, дает кров. Наверное, я Бог!</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Человек думает: Собака очень  сообразительно существо. За кусочек лакомства быстро приучается  выполнять несложные трюки.</p>,
#  <p>Собака думает: Человек очень  сообразительное существо. За несложные трюки быстро приучается давать  лакомство.</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Чебурашка рассматривает себя в  зеркало.</p>,
#  <p>- Может быть, мне жениться?  Или замуж выйти…</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Чем отличается мужское  общежитие от женского? В женском общежитии посуду моют после еды, а в  мужском – перед едой.</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Маленькие мальчик и девочка  играют в песочнице.</p>,
#  <p>- У меня есть совочек.</p>,
#  <p>- А у меня ведерко.</p>,
#  <p>- У меня мячик.</p>,
#  <p>- А у меня скакалка.</p>,
#  <p>- У меня машинка.</p>,
#  <p>- А у меня кукла.</p>,
#  <p>Когда игрушек уже не осталось,  мальчик снял штанишки:</p>,
#  <p>- А у меня вот что есть!</p>,
#  <p>Девочке ответить было нечем,  она заплакала и убежала домой. Через какое-то время возвращается  спокойная и гордая:</p>,
#  <p>- А мне мама сказала, что,  когда я вырасту, у меня таких будет, сколько захочу!</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>На приеме у психотерапевта:</p>,
#  <p>- Доктор, меня все игнорируют.</p>,
#  <p>- Следующий!</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Зайчик и белочка пришли к  мудрой сове:</p>,
#  <p>- Мудрая сова, вот мы любим  друг друга, живем вместе, а у нас почему-то нет детишек. Это потому что  мы зайчик и белочка?</p>,
#  <p>- Нет! Это потому что вы  мальчик и мальчик.</p>,
#  <p><img alt="" src="/img/pages/regular_smile.gif"/></p>,
#  <p>Рабинович каждый день ходит в  синагогу и молится:</p>,
#  <p>- Господи, помоги мне выиграть  в лотерею. Ну, пожалуйста, помоги мне выиграть в лотерею.</p>,
#  <p>Это продолжается несколько  месяцев. Во время очередной молитвы откуда-то сверху вдруг раздается  божественный голос:</p>,
#  <p>- Рабинович, купи хотя бы один  лотерейный билет!</p>]

# %%
# Чтобы извлечь из ссылки текст:
[x.text for x in links]
# Out:
# ['Нет товаров',
#  'Продолжить покупки',
#  'В  Москве проходит тендер на строительство здания. Проект представляет  немецкая компания. Смета 10 миллионов. Затем турецкая компания – 5  миллионов. Подходит черед российской компании. У них смета 15 миллионов.',
#  '- Почему так много?',
#  '- Ну, как же? 5 миллионов нам,  5 миллионов вам и 5 туркам, чтобы строили.',
#  'И они выигрывают тендер!',
#  '',
#  'Один бизнесмен хотел жениться,  но у него было три подружки, и он не знал какую из них выбрать. Решил  их проверить: дал каждой по 1000 долларов. Одна потратила все деньги на  себя, другая купила что-то для хозяйства, а третья вложила в дело и  получила прибыль. Какую же из трех он выбрал? Ту, у которой грудь  больше!',
#  '',
#  'Едет русский на своем  автомобиле по Украине. Его останавливает украинский гаишник:',
#  '- Вы нарушили правила, пишите  объяснительную записку на украинском языке.',
#  '- Но я не умею, на  украинском!..',
#  '- Тогда отберем права.',
#  'Что делать? Русский положил в  чистый лист 100 долларов. Гаишник смотрит.',
#  '-Ну, вот, говорите, что не  умеете, а половину уже написали!',
#  '',
#  'Поздний вечер. Мужа нет дома.  Жена волнуется.',
#  '- Наверное, он с другой  женщиной, я давно подозревала…',
#  'Теща:',
#  '- Зачем ты думаешь сразу о  плохом? Может быть, он просто попал под машину…',
#  '',
#  'Женщины бывают или «прелесть,  какие глупенькие», или «ужас, какие дуры!»',
#  '',
#  'Урок в кавказской школе. Учитель  вызвал ученика и попросил начертить равнобедренный треугольник. Мальчик  начертил. Учитель:',
#  '- А теперь докажи, что он  равнобедренный.',
#  '- Мамой клянусь, равнобедренный!',
#  '',
#  'Объявлен  международный тендер на прокладку трубопровода по дну океана из Европы в  Америку. Проект представляет немецкая компания, показывает графики,  схемы, сметы.',
#  '- Мы будем  работать три года. Начнем с двух сторон. Когда дойдем до середины,  гарантируем, что расхождение будет не более десяти метров.',
#  'Японская  компания, показывает проект:',
#  '- Мы будем  работать два года. Начнем с двух сторон. Когда дойдем до середины,  гарантируем, что расхождение будет не более пяти метров.',
#  'Русская  компания:',
#  '- Мы будем  работать полгода. Начнем с двух сторон. Ничего не гарантируем. В крайнем  случае, будет две трубы.',
#  '',
#  'Солдат  спрашивает у прапорщика:',
#  '- Товарищ  прапорщик, а крокодилы летают?',
#  '- Конечно,  нет! Ерунда какая!',
#  '- Да?.. А  товарищ лейтенант сказал, что летают…',
#  '- Ну, они  летают, но только низенько-низенько.',
#  '- А товарищ  лейтенант сказал, что высоко.',
#  '- Они  сначала низенько-низенько, а потом как взмоют!',
#  '',
#  'Разговаривают  два солдатика.',
#  '- Слушай,  давай над лейтенантом приколемся.',
#  '- Ага, над деканом уже  прикололись…',
#  '',
#  'Штирлиц  проснулся в камере. Как сюда попал, не помнит. Думает: «Если войдут  русские, скажу, что я полковник Исаев. Если немцы – штандартенфюрер  Штирлиц».',
#  'Входит  милиционер:',
#  '-Ну, и  напились Вы вчера, товарищ Тихонов!',
#  '',
#  'Москвичей  нигде не любят, особенно в Москве…',
#  '',
#  'Белорусские  новости: «Александр Григорьевич Лукашенко заявил, что он не хочет больше  быть президентом. Коронация назначена на вторник».',
#  '',
#  'У одного  мужика была бахча, но кто-то повадился таскать с нее арбузы. Чтобы это  прекратить, он поставил табличку «Внимание! Один из арбузов отравлен».  На следующий день видит, на табличке подписано: «Теперь их два…»',
#  '',
#  'Китаец был в  Москве. Когда вернулся домой, родственники его спрашивают:',
#  '-Ну, как  тебе Москва?',
#  '-Хороший  город, чистый и народу мало!',
#  '',
#  'Богатый  студент пришел на экзамен, но не подготовился. Положил в чистую тетрадь  пять тысяч долларов и написал: «Профессор, по штуке за балл». Когда ему  вернули тетрадь с результатами, там лежало три тысячи и рукой профессора  написано: «Сдача».',
#  '',
#  'Из ПДД для  блондинок: «Действие знака «Обгон запрещен» распространяется не только  на автомобили красного цвета».',
#  '',
#  'Один  строитель всю жизнь строил мосты, а когда ушел на пенсию, его дело  продолжил сын. Однажды сын пришел к отцу и с гордостью говорит:',
#  '-  Папа, я достроил мост, который ты строил тридцать лет!',
#  '-  Сынок, пока строился этот мост, я тебя вырастил и выучил. А ты как  будешь кормить свою семью?',
#  '',
#  'Разговор  двух приятелей:',
#  '- Я  свою жену называю «зайка», «рыбка», «птичка»…',
#  '-  Ну, а она что?',
#  '-  Уши развесит, глаза выпучит и клювом щелкает!',
#  '',
#  'Что такое рай? Это английский  дом, китайская кухня, американская зарплата и русская жена.',
#  'А что такое ад? Это китайский  дом, английская кухня, русская зарплата и американская жена.',
#  '',
#  'Если  мужчине сказать: «Ты такой же дурак, как Вася!» Он спросит, почему это  он дурак?',
#  'Если  женщине сказать: «Ты такая же дура, как Маша!» Она возмутится: Почему  это я, как Маша?!»',
#  '',
#  'МУЖСКОЙ РЕЦЕПТ  ШАРЛОТКИ (простого яблочного пирога).',
#  'Возьмите  из холодильника 10 яиц, положите на стол оставшиеся семь и вытрите пол.  Возьмите большую миску и разбейте об ее край яйца. Вылейте их  содержимое в миску. Протрите стол. Итак, у вас в миске 5 яиц. Теперь  возьмите миксер, вставьте венчики и начните взбивать. Попробуйте еще раз  вставить венчики, теперь до щелчка. Взбивайте. Вымойте лицо, шею, руки,  спину, уши. В итоге у вас в миске осталось два взбитых яйца. Обклейте  стены и потолок кухни газетой, накройте мебель какой-нибудь тканью –  пора доставать муку… Насыпьте 200 г в стакан, затем высыпьте в миску.  Оставшиеся 800 г аккуратно соберите обратно в пакет. Взбивайте. Примите  душ. Возьмите 4 больших яблока и нож. Приготовьте йод, пластырь и бинт.  Очистите яблоки. Обработайте большой палец йодом и забинтуйте его.  Нарежьте яблоки кубиками и помните, вам понадобится 2 яблока, так что в  процессе готовки можно съесть только половину. Обработайте йодом  указательный и средний пальцы. Единственное оставшееся и уже нарезанное  яблоко сбросьте в миску, подберите с пола упавшие кусочки, помойте их и  тоже положите в миску. Взбивайте все миксером. Отмойте холодильник.  Теперь выливайте содержимое в сковородку и ставьте в духовку. Подождите  час и, не увидев ощутимых изменений, включите духовку. Проснувшись, не  звоните в Службу спасения, а просто выключите духовку и откройте окна...',
#  '',
#  'Объявление в  газете: «Потомственный алкоголик в четвертом поколении быстро и  безболезненно снимет любую кодировку».',
#  '',
#  'Разговор двух подростков:',
#  '- Мне отец привез из Африки  большого попугая за тысячу долларов!',
#  '- Красивый попугай?',
#  '- Красивый!',
#  '- Говорящий?',
#  '- Говорящий!',
#  '- Вкусный?',
#  '- Ты что?! Попугай штуку  баксов стоит. Конечно, вкусный!',
#  '',
#  '- Сынок, с 23-им февраля!',
#  '- Пап, не каркай, может, я еще  поступлю…',
#  '',
#  '- У меня на даче дом-на.',
#  '- Зачем тебе?',
#  '- Я там живу-на!',
#  '',
#  '- Будет ли Третья мировая  ойна?',
#  '- Будет.',
#  '- А сколько после войны будет  стоить в Америке банка «Кока-колы»?',
#  '- Один рубль.',
#  '',
#  'Студент духовной семинарии  полюбил дочку олигарха. Он решили пожениться. Пришел жених поговорить с  отцом невесты.',
#  '- А Вы знаете, что моя дочь  привыкла ни в чем себе не отказывать? Она шубы и драгоценности через  день покупает. Вы сможете ей это обеспечить?',
#  '- Боженька поможет!',
#  '- А еще она дорогие машины  меняет по нескольку раз в год.',
#  '- Боженька поможет!',
#  '- Она еще часто за границу  ездит, на отдых, на шопинг…',
#  '- Боженька поможет!',
#  'Позже дочка спрашивает:',
#  '- Папа, тебе понравился мой  жених?',
#  '- Он, конечно, полный ноль, но  приятно, что меня боженькой называет…',
#  '',
#  'Адам спрашивает у Бога:',
#  '- Господи, почему ты сделал  Еву такой красивой?',
#  '- Чтобы она тебе понравилась,  сын мой.',
#  '- Боже, но почему же ты сделал  ее такой глупой?',
#  '- А это, чтобы ты ей  понравился…',
#  '',
#  'Приехали в Новую Зеландию три  приятеля – биолог, физик и математик. Едут на машине. Видят, на зеленом  лугу пасется черная овца.',
#  'Биолог: Это говорит о том, что  здесь водятся черные овцы.',
#  'Физик: Это говорит о том, что  здесь водится по крайней мере одна черная овца.',
#  'Математик: Это говорит о том,  здесь водится по крайней мере одна овца, черная по крайней мере с одной  стороны.',
#  '',
#  'Пошли муж и жена на охоту. Он  дал ей ружье.',
#  '- Я на тебя из леса выгоню  лося, и ты тогда стреляй.',
#  'Ушел в лес. Вдруг слышит  выстрелы, шум, крики. Подбегает, а там его жена и какой-то мужик. Жена  наставила на него ружье и кричит:',
#  '- Это мой лось! Отойди!',
#  '- Ладно-ладно, твой. Можно, я  только седло сниму?',
#  '',
#  'Подходит\xa0 школе  к Вовочке девочка:',
#  '- Вовочка, у вас дома ТАКОЕ!',
#  'Потом подошел и директор  школы:',
#  '- Вовочка, иди домой, у вас  дома ТАКОЕ!',
#  'На улице знакомые тоже  говорили:',
#  '- Вовочка, у вас дома ТАКОЕ!',
#  'Прибежал он домой. И ему  говорят:',
#  '- Вовочка, у нас ТАКОЕ! Твой  брат Саша бомбу в царя бросил…',
#  '',
#  'Немец в Лондоне заходит в паб:',
#  '- Two Martini,  please.',
#  '- Dry?',
#  '- Nein, nur zwei!',
#  '',
#  'В зоопарке  медведь жалуется директору:',
#  '- Переведите меня в другую  клетку, я так больше жить не могу! У меня справа обезьяна, а слева  жираф. Обезьяна весь день анекдоты рассказывает, а жираф всю ночь  смеется.',
#  '',
#  'Два электрика в подъезде  что-то чинят и спорят. Идет бабушка.',
#  '- Бабушка! Подержи провод.',
#  '- Ну, вот, я же тебе говорил,  что это ноль, а ты «фаза-фаза»…',
#  '',
#  '- Правильно говорят, что  блондинки глупые! Моя жена была брюнеткой, вчера днем перекрасилась в  блондинку, а вечером устроила скандал, когда нашла в постели черные  волосы.',
#  '',
#  'Собака думает: Человек обо мне  заботится, кормит меня, поит, дает кров. Наверное, он Бог!',
#  'Кошка думает: Человек обо мне  заботится, кормит меня, поит, дает кров. Наверное, я Бог!',
#  '',
#  'Человек думает: Собака очень  сообразительно существо. За кусочек лакомства быстро приучается  выполнять несложные трюки.',
#  'Собака думает: Человек очень  сообразительное существо. За несложные трюки быстро приучается давать  лакомство.',
#  '',
#  'Чебурашка рассматривает себя в  зеркало.',
#  '- Может быть, мне жениться?  Или замуж выйти…',
#  '',
#  'Чем отличается мужское  общежитие от женского? В женском общежитии посуду моют после еды, а в  мужском – перед едой.',
#  '',
#  'Маленькие мальчик и девочка  играют в песочнице.',
#  '- У меня есть совочек.',
#  '- А у меня ведерко.',
#  '- У меня мячик.',
#  '- А у меня скакалка.',
#  '- У меня машинка.',
#  '- А у меня кукла.',
#  'Когда игрушек уже не осталось,  мальчик снял штанишки:',
#  '- А у меня вот что есть!',
#  'Девочке ответить было нечем,  она заплакала и убежала домой. Через какое-то время возвращается  спокойная и гордая:',
#  '- А мне мама сказала, что,  когда я вырасту, у меня таких будет, сколько захочу!',
#  '',
#  'На приеме у психотерапевта:',
#  '- Доктор, меня все игнорируют.',
#  '- Следующий!',
#  '',
#  'Зайчик и белочка пришли к  мудрой сове:',
#  '- Мудрая сова, вот мы любим  друг друга, живем вместе, а у нас почему-то нет детишек. Это потому что  мы зайчик и белочка?',
#  '- Нет! Это потому что вы  мальчик и мальчик.',
#  '',
#  'Рабинович каждый день ходит в  синагогу и молится:',
#  '- Господи, помоги мне выиграть  в лотерею. Ну, пожалуйста, помоги мне выиграть в лотерею.',
#  'Это продолжается несколько  месяцев. Во время очередной молитвы откуда-то сверху вдруг раздается  божественный голос:',
#  '- Рабинович, купи хотя бы один  лотерейный билет!']

# %%
# Magic_2 - Извлекаем инфу с описанием товаров
# soup.find_all('a', class_='woocommerce-LoopProduct-link woocommerce-loop-product__link')

# Оставляем только текстовую информацию
[t.text for t in soup.find_all('p')]
# links[0]
# Out:
# ['Нет товаров',
#  'Продолжить покупки',
#  'В  Москве проходит тендер на строительство здания. Проект представляет  немецкая компания. Смета 10 миллионов. Затем турецкая компания – 5  миллионов. Подходит черед российской компании. У них смета 15 миллионов.',
#  '- Почему так много?',
#  '- Ну, как же? 5 миллионов нам,  5 миллионов вам и 5 туркам, чтобы строили.',
#  'И они выигрывают тендер!',
#  '',
#  'Один бизнесмен хотел жениться,  но у него было три подружки, и он не знал какую из них выбрать. Решил  их проверить: дал каждой по 1000 долларов. Одна потратила все деньги на  себя, другая купила что-то для хозяйства, а третья вложила в дело и  получила прибыль. Какую же из трех он выбрал? Ту, у которой грудь  больше!',
#  '',
#  'Едет русский на своем  автомобиле по Украине. Его останавливает украинский гаишник:',
#  '- Вы нарушили правила, пишите  объяснительную записку на украинском языке.',
#  '- Но я не умею, на  украинском!..',
#  '- Тогда отберем права.',
#  'Что делать? Русский положил в  чистый лист 100 долларов. Гаишник смотрит.',
#  '-Ну, вот, говорите, что не  умеете, а половину уже написали!',
#  '',
#  'Поздний вечер. Мужа нет дома.  Жена волнуется.',
#  '- Наверное, он с другой  женщиной, я давно подозревала…',
#  'Теща:',
#  '- Зачем ты думаешь сразу о  плохом? Может быть, он просто попал под машину…',
#  '',
#  'Женщины бывают или «прелесть,  какие глупенькие», или «ужас, какие дуры!»',
#  '',
#  'Урок в кавказской школе. Учитель  вызвал ученика и попросил начертить равнобедренный треугольник. Мальчик  начертил. Учитель:',
#  '- А теперь докажи, что он  равнобедренный.',
#  '- Мамой клянусь, равнобедренный!',
#  '',
#  'Объявлен  международный тендер на прокладку трубопровода по дну океана из Европы в  Америку. Проект представляет немецкая компания, показывает графики,  схемы, сметы.',
#  '- Мы будем  работать три года. Начнем с двух сторон. Когда дойдем до середины,  гарантируем, что расхождение будет не более десяти метров.',
#  'Японская  компания, показывает проект:',
#  '- Мы будем  работать два года. Начнем с двух сторон. Когда дойдем до середины,  гарантируем, что расхождение будет не более пяти метров.',
#  'Русская  компания:',
#  '- Мы будем  работать полгода. Начнем с двух сторон. Ничего не гарантируем. В крайнем  случае, будет две трубы.',
#  '',
#  'Солдат  спрашивает у прапорщика:',
#  '- Товарищ  прапорщик, а крокодилы летают?',
#  '- Конечно,  нет! Ерунда какая!',
#  '- Да?.. А  товарищ лейтенант сказал, что летают…',
#  '- Ну, они  летают, но только низенько-низенько.',
#  '- А товарищ  лейтенант сказал, что высоко.',
#  '- Они  сначала низенько-низенько, а потом как взмоют!',
#  '',
#  'Разговаривают  два солдатика.',
#  '- Слушай,  давай над лейтенантом приколемся.',
#  '- Ага, над деканом уже  прикололись…',
#  '',
#  'Штирлиц  проснулся в камере. Как сюда попал, не помнит. Думает: «Если войдут  русские, скажу, что я полковник Исаев. Если немцы – штандартенфюрер  Штирлиц».',
#  'Входит  милиционер:',
#  '-Ну, и  напились Вы вчера, товарищ Тихонов!',
#  '',
#  'Москвичей  нигде не любят, особенно в Москве…',
#  '',
#  'Белорусские  новости: «Александр Григорьевич Лукашенко заявил, что он не хочет больше  быть президентом. Коронация назначена на вторник».',
#  '',
#  'У одного  мужика была бахча, но кто-то повадился таскать с нее арбузы. Чтобы это  прекратить, он поставил табличку «Внимание! Один из арбузов отравлен».  На следующий день видит, на табличке подписано: «Теперь их два…»',
#  '',
#  'Китаец был в  Москве. Когда вернулся домой, родственники его спрашивают:',
#  '-Ну, как  тебе Москва?',
#  '-Хороший  город, чистый и народу мало!',
#  '',
#  'Богатый  студент пришел на экзамен, но не подготовился. Положил в чистую тетрадь  пять тысяч долларов и написал: «Профессор, по штуке за балл». Когда ему  вернули тетрадь с результатами, там лежало три тысячи и рукой профессора  написано: «Сдача».',
#  '',
#  'Из ПДД для  блондинок: «Действие знака «Обгон запрещен» распространяется не только  на автомобили красного цвета».',
#  '',
#  'Один  строитель всю жизнь строил мосты, а когда ушел на пенсию, его дело  продолжил сын. Однажды сын пришел к отцу и с гордостью говорит:',
#  '-  Папа, я достроил мост, который ты строил тридцать лет!',
#  '-  Сынок, пока строился этот мост, я тебя вырастил и выучил. А ты как  будешь кормить свою семью?',
#  '',
#  'Разговор  двух приятелей:',
#  '- Я  свою жену называю «зайка», «рыбка», «птичка»…',
#  '-  Ну, а она что?',
#  '-  Уши развесит, глаза выпучит и клювом щелкает!',
#  '',
#  'Что такое рай? Это английский  дом, китайская кухня, американская зарплата и русская жена.',
#  'А что такое ад? Это китайский  дом, английская кухня, русская зарплата и американская жена.',
#  '',
#  'Если  мужчине сказать: «Ты такой же дурак, как Вася!» Он спросит, почему это  он дурак?',
#  'Если  женщине сказать: «Ты такая же дура, как Маша!» Она возмутится: Почему  это я, как Маша?!»',
#  '',
#  'МУЖСКОЙ РЕЦЕПТ  ШАРЛОТКИ (простого яблочного пирога).',
#  'Возьмите  из холодильника 10 яиц, положите на стол оставшиеся семь и вытрите пол.  Возьмите большую миску и разбейте об ее край яйца. Вылейте их  содержимое в миску. Протрите стол. Итак, у вас в миске 5 яиц. Теперь  возьмите миксер, вставьте венчики и начните взбивать. Попробуйте еще раз  вставить венчики, теперь до щелчка. Взбивайте. Вымойте лицо, шею, руки,  спину, уши. В итоге у вас в миске осталось два взбитых яйца. Обклейте  стены и потолок кухни газетой, накройте мебель какой-нибудь тканью –  пора доставать муку… Насыпьте 200 г в стакан, затем высыпьте в миску.  Оставшиеся 800 г аккуратно соберите обратно в пакет. Взбивайте. Примите  душ. Возьмите 4 больших яблока и нож. Приготовьте йод, пластырь и бинт.  Очистите яблоки. Обработайте большой палец йодом и забинтуйте его.  Нарежьте яблоки кубиками и помните, вам понадобится 2 яблока, так что в  процессе готовки можно съесть только половину. Обработайте йодом  указательный и средний пальцы. Единственное оставшееся и уже нарезанное  яблоко сбросьте в миску, подберите с пола упавшие кусочки, помойте их и  тоже положите в миску. Взбивайте все миксером. Отмойте холодильник.  Теперь выливайте содержимое в сковородку и ставьте в духовку. Подождите  час и, не увидев ощутимых изменений, включите духовку. Проснувшись, не  звоните в Службу спасения, а просто выключите духовку и откройте окна...',
#  '',
#  'Объявление в  газете: «Потомственный алкоголик в четвертом поколении быстро и  безболезненно снимет любую кодировку».',
#  '',
#  'Разговор двух подростков:',
#  '- Мне отец привез из Африки  большого попугая за тысячу долларов!',
#  '- Красивый попугай?',
#  '- Красивый!',
#  '- Говорящий?',
#  '- Говорящий!',
#  '- Вкусный?',
#  '- Ты что?! Попугай штуку  баксов стоит. Конечно, вкусный!',
#  '',
#  '- Сынок, с 23-им февраля!',
#  '- Пап, не каркай, может, я еще  поступлю…',
#  '',
#  '- У меня на даче дом-на.',
#  '- Зачем тебе?',
#  '- Я там живу-на!',
#  '',
#  '- Будет ли Третья мировая  ойна?',
#  '- Будет.',
#  '- А сколько после войны будет  стоить в Америке банка «Кока-колы»?',
#  '- Один рубль.',
#  '',
#  'Студент духовной семинарии  полюбил дочку олигарха. Он решили пожениться. Пришел жених поговорить с  отцом невесты.',
#  '- А Вы знаете, что моя дочь  привыкла ни в чем себе не отказывать? Она шубы и драгоценности через  день покупает. Вы сможете ей это обеспечить?',
#  '- Боженька поможет!',
#  '- А еще она дорогие машины  меняет по нескольку раз в год.',
#  '- Боженька поможет!',
#  '- Она еще часто за границу  ездит, на отдых, на шопинг…',
#  '- Боженька поможет!',
#  'Позже дочка спрашивает:',
#  '- Папа, тебе понравился мой  жених?',
#  '- Он, конечно, полный ноль, но  приятно, что меня боженькой называет…',
#  '',
#  'Адам спрашивает у Бога:',
#  '- Господи, почему ты сделал  Еву такой красивой?',
#  '- Чтобы она тебе понравилась,  сын мой.',
#  '- Боже, но почему же ты сделал  ее такой глупой?',
#  '- А это, чтобы ты ей  понравился…',
#  '',
#  'Приехали в Новую Зеландию три  приятеля – биолог, физик и математик. Едут на машине. Видят, на зеленом  лугу пасется черная овца.',
#  'Биолог: Это говорит о том, что  здесь водятся черные овцы.',
#  'Физик: Это говорит о том, что  здесь водится по крайней мере одна черная овца.',
#  'Математик: Это говорит о том,  здесь водится по крайней мере одна овца, черная по крайней мере с одной  стороны.',
#  '',
#  'Пошли муж и жена на охоту. Он  дал ей ружье.',
#  '- Я на тебя из леса выгоню  лося, и ты тогда стреляй.',
#  'Ушел в лес. Вдруг слышит  выстрелы, шум, крики. Подбегает, а там его жена и какой-то мужик. Жена  наставила на него ружье и кричит:',
#  '- Это мой лось! Отойди!',
#  '- Ладно-ладно, твой. Можно, я  только седло сниму?',
#  '',
#  'Подходит\xa0 школе  к Вовочке девочка:',
#  '- Вовочка, у вас дома ТАКОЕ!',
#  'Потом подошел и директор  школы:',
#  '- Вовочка, иди домой, у вас  дома ТАКОЕ!',
#  'На улице знакомые тоже  говорили:',
#  '- Вовочка, у вас дома ТАКОЕ!',
#  'Прибежал он домой. И ему  говорят:',
#  '- Вовочка, у нас ТАКОЕ! Твой  брат Саша бомбу в царя бросил…',
#  '',
#  'Немец в Лондоне заходит в паб:',
#  '- Two Martini,  please.',
#  '- Dry?',
#  '- Nein, nur zwei!',
#  '',
#  'В зоопарке  медведь жалуется директору:',
#  '- Переведите меня в другую  клетку, я так больше жить не могу! У меня справа обезьяна, а слева  жираф. Обезьяна весь день анекдоты рассказывает, а жираф всю ночь  смеется.',
#  '',
#  'Два электрика в подъезде  что-то чинят и спорят. Идет бабушка.',
#  '- Бабушка! Подержи провод.',
#  '- Ну, вот, я же тебе говорил,  что это ноль, а ты «фаза-фаза»…',
#  '',
#  '- Правильно говорят, что  блондинки глупые! Моя жена была брюнеткой, вчера днем перекрасилась в  блондинку, а вечером устроила скандал, когда нашла в постели черные  волосы.',
#  '',
#  'Собака думает: Человек обо мне  заботится, кормит меня, поит, дает кров. Наверное, он Бог!',
#  'Кошка думает: Человек обо мне  заботится, кормит меня, поит, дает кров. Наверное, я Бог!',
#  '',
#  'Человек думает: Собака очень  сообразительно существо. За кусочек лакомства быстро приучается  выполнять несложные трюки.',
#  'Собака думает: Человек очень  сообразительное существо. За несложные трюки быстро приучается давать  лакомство.',
#  '',
#  'Чебурашка рассматривает себя в  зеркало.',
#  '- Может быть, мне жениться?  Или замуж выйти…',
#  '',
#  'Чем отличается мужское  общежитие от женского? В женском общежитии посуду моют после еды, а в  мужском – перед едой.',
#  '',
#  'Маленькие мальчик и девочка  играют в песочнице.',
#  '- У меня есть совочек.',
#  '- А у меня ведерко.',
#  '- У меня мячик.',
#  '- А у меня скакалка.',
#  '- У меня машинка.',
#  '- А у меня кукла.',
#  'Когда игрушек уже не осталось,  мальчик снял штанишки:',
#  '- А у меня вот что есть!',
#  'Девочке ответить было нечем,  она заплакала и убежала домой. Через какое-то время возвращается  спокойная и гордая:',
#  '- А мне мама сказала, что,  когда я вырасту, у меня таких будет, сколько захочу!',
#  '',
#  'На приеме у психотерапевта:',
#  '- Доктор, меня все игнорируют.',
#  '- Следующий!',
#  '',
#  'Зайчик и белочка пришли к  мудрой сове:',
#  '- Мудрая сова, вот мы любим  друг друга, живем вместе, а у нас почему-то нет детишек. Это потому что  мы зайчик и белочка?',
#  '- Нет! Это потому что вы  мальчик и мальчик.',
#  '',
#  'Рабинович каждый день ходит в  синагогу и молится:',
#  '- Господи, помоги мне выиграть  в лотерею. Ну, пожалуйста, помоги мне выиграть в лотерею.',
#  'Это продолжается несколько  месяцев. Во время очередной молитвы откуда-то сверху вдруг раздается  божественный голос:',
#  '- Рабинович, купи хотя бы один  лотерейный билет!']

# %%
# Избавляемся от всего лишнего
# [t.text.strip() for t in soup.find_all('a', class_='woocommerce-LoopProduct-link woocommerce-loop-product__link')]

# Сохраняем в переменную для дальнейшего использования наименования товаров
titles = [t.text.strip().split('\n')[0] for t in soup.find_all('p')]
titles
# Out:
# ['Нет товаров',
#  'Продолжить покупки',
#  'В  Москве проходит тендер на строительство здания. Проект представляет  немецкая компания. Смета 10 миллионов. Затем турецкая компания – 5  миллионов. Подходит черед российской компании. У них смета 15 миллионов.',
#  '- Почему так много?',
#  '- Ну, как же? 5 миллионов нам,  5 миллионов вам и 5 туркам, чтобы строили.',
#  'И они выигрывают тендер!',
#  '',
#  'Один бизнесмен хотел жениться,  но у него было три подружки, и он не знал какую из них выбрать. Решил  их проверить: дал каждой по 1000 долларов. Одна потратила все деньги на  себя, другая купила что-то для хозяйства, а третья вложила в дело и  получила прибыль. Какую же из трех он выбрал? Ту, у которой грудь  больше!',
#  '',
#  'Едет русский на своем  автомобиле по Украине. Его останавливает украинский гаишник:',
#  '- Вы нарушили правила, пишите  объяснительную записку на украинском языке.',
#  '- Но я не умею, на  украинском!..',
#  '- Тогда отберем права.',
#  'Что делать? Русский положил в  чистый лист 100 долларов. Гаишник смотрит.',
#  '-Ну, вот, говорите, что не  умеете, а половину уже написали!',
#  '',
#  'Поздний вечер. Мужа нет дома.  Жена волнуется.',
#  '- Наверное, он с другой  женщиной, я давно подозревала…',
#  'Теща:',
#  '- Зачем ты думаешь сразу о  плохом? Может быть, он просто попал под машину…',
#  '',
#  'Женщины бывают или «прелесть,  какие глупенькие», или «ужас, какие дуры!»',
#  '',
#  'Урок в кавказской школе. Учитель  вызвал ученика и попросил начертить равнобедренный треугольник. Мальчик  начертил. Учитель:',
#  '- А теперь докажи, что он  равнобедренный.',
#  '- Мамой клянусь, равнобедренный!',
#  '',
#  'Объявлен  международный тендер на прокладку трубопровода по дну океана из Европы в  Америку. Проект представляет немецкая компания, показывает графики,  схемы, сметы.',
#  '- Мы будем  работать три года. Начнем с двух сторон. Когда дойдем до середины,  гарантируем, что расхождение будет не более десяти метров.',
#  'Японская  компания, показывает проект:',
#  '- Мы будем  работать два года. Начнем с двух сторон. Когда дойдем до середины,  гарантируем, что расхождение будет не более пяти метров.',
#  'Русская  компания:',
#  '- Мы будем  работать полгода. Начнем с двух сторон. Ничего не гарантируем. В крайнем  случае, будет две трубы.',
#  '',
#  'Солдат  спрашивает у прапорщика:',
#  '- Товарищ  прапорщик, а крокодилы летают?',
#  '- Конечно,  нет! Ерунда какая!',
#  '- Да?.. А  товарищ лейтенант сказал, что летают…',
#  '- Ну, они  летают, но только низенько-низенько.',
#  '- А товарищ  лейтенант сказал, что высоко.',
#  '- Они  сначала низенько-низенько, а потом как взмоют!',
#  '',
#  'Разговаривают  два солдатика.',
#  '- Слушай,  давай над лейтенантом приколемся.',
#  '- Ага, над деканом уже  прикололись…',
#  '',
#  'Штирлиц  проснулся в камере. Как сюда попал, не помнит. Думает: «Если войдут  русские, скажу, что я полковник Исаев. Если немцы – штандартенфюрер  Штирлиц».',
#  'Входит  милиционер:',
#  '-Ну, и  напились Вы вчера, товарищ Тихонов!',
#  '',
#  'Москвичей  нигде не любят, особенно в Москве…',
#  '',
#  'Белорусские  новости: «Александр Григорьевич Лукашенко заявил, что он не хочет больше  быть президентом. Коронация назначена на вторник».',
#  '',
#  'У одного  мужика была бахча, но кто-то повадился таскать с нее арбузы. Чтобы это  прекратить, он поставил табличку «Внимание! Один из арбузов отравлен».  На следующий день видит, на табличке подписано: «Теперь их два…»',
#  '',
#  'Китаец был в  Москве. Когда вернулся домой, родственники его спрашивают:',
#  '-Ну, как  тебе Москва?',
#  '-Хороший  город, чистый и народу мало!',
#  '',
#  'Богатый  студент пришел на экзамен, но не подготовился. Положил в чистую тетрадь  пять тысяч долларов и написал: «Профессор, по штуке за балл». Когда ему  вернули тетрадь с результатами, там лежало три тысячи и рукой профессора  написано: «Сдача».',
#  '',
#  'Из ПДД для  блондинок: «Действие знака «Обгон запрещен» распространяется не только  на автомобили красного цвета».',
#  '',
#  'Один  строитель всю жизнь строил мосты, а когда ушел на пенсию, его дело  продолжил сын. Однажды сын пришел к отцу и с гордостью говорит:',
#  '-  Папа, я достроил мост, который ты строил тридцать лет!',
#  '-  Сынок, пока строился этот мост, я тебя вырастил и выучил. А ты как  будешь кормить свою семью?',
#  '',
#  'Разговор  двух приятелей:',
#  '- Я  свою жену называю «зайка», «рыбка», «птичка»…',
#  '-  Ну, а она что?',
#  '-  Уши развесит, глаза выпучит и клювом щелкает!',
#  '',
#  'Что такое рай? Это английский  дом, китайская кухня, американская зарплата и русская жена.',
#  'А что такое ад? Это китайский  дом, английская кухня, русская зарплата и американская жена.',
#  '',
#  'Если  мужчине сказать: «Ты такой же дурак, как Вася!» Он спросит, почему это  он дурак?',
#  'Если  женщине сказать: «Ты такая же дура, как Маша!» Она возмутится: Почему  это я, как Маша?!»',
#  '',
#  'МУЖСКОЙ РЕЦЕПТ  ШАРЛОТКИ (простого яблочного пирога).',
#  'Возьмите  из холодильника 10 яиц, положите на стол оставшиеся семь и вытрите пол.  Возьмите большую миску и разбейте об ее край яйца. Вылейте их  содержимое в миску. Протрите стол. Итак, у вас в миске 5 яиц. Теперь  возьмите миксер, вставьте венчики и начните взбивать. Попробуйте еще раз  вставить венчики, теперь до щелчка. Взбивайте. Вымойте лицо, шею, руки,  спину, уши. В итоге у вас в миске осталось два взбитых яйца. Обклейте  стены и потолок кухни газетой, накройте мебель какой-нибудь тканью –  пора доставать муку… Насыпьте 200 г в стакан, затем высыпьте в миску.  Оставшиеся 800 г аккуратно соберите обратно в пакет. Взбивайте. Примите  душ. Возьмите 4 больших яблока и нож. Приготовьте йод, пластырь и бинт.  Очистите яблоки. Обработайте большой палец йодом и забинтуйте его.  Нарежьте яблоки кубиками и помните, вам понадобится 2 яблока, так что в  процессе готовки можно съесть только половину. Обработайте йодом  указательный и средний пальцы. Единственное оставшееся и уже нарезанное  яблоко сбросьте в миску, подберите с пола упавшие кусочки, помойте их и  тоже положите в миску. Взбивайте все миксером. Отмойте холодильник.  Теперь выливайте содержимое в сковородку и ставьте в духовку. Подождите  час и, не увидев ощутимых изменений, включите духовку. Проснувшись, не  звоните в Службу спасения, а просто выключите духовку и откройте окна...',
#  '',
#  'Объявление в  газете: «Потомственный алкоголик в четвертом поколении быстро и  безболезненно снимет любую кодировку».',
#  '',
#  'Разговор двух подростков:',
#  '- Мне отец привез из Африки  большого попугая за тысячу долларов!',
#  '- Красивый попугай?',
#  '- Красивый!',
#  '- Говорящий?',
#  '- Говорящий!',
#  '- Вкусный?',
#  '- Ты что?! Попугай штуку  баксов стоит. Конечно, вкусный!',
#  '',
#  '- Сынок, с 23-им февраля!',
#  '- Пап, не каркай, может, я еще  поступлю…',
#  '',
#  '- У меня на даче дом-на.',
#  '- Зачем тебе?',
#  '- Я там живу-на!',
#  '',
#  '- Будет ли Третья мировая  ойна?',
#  '- Будет.',
#  '- А сколько после войны будет  стоить в Америке банка «Кока-колы»?',
#  '- Один рубль.',
#  '',
#  'Студент духовной семинарии  полюбил дочку олигарха. Он решили пожениться. Пришел жених поговорить с  отцом невесты.',
#  '- А Вы знаете, что моя дочь  привыкла ни в чем себе не отказывать? Она шубы и драгоценности через  день покупает. Вы сможете ей это обеспечить?',
#  '- Боженька поможет!',
#  '- А еще она дорогие машины  меняет по нескольку раз в год.',
#  '- Боженька поможет!',
#  '- Она еще часто за границу  ездит, на отдых, на шопинг…',
#  '- Боженька поможет!',
#  'Позже дочка спрашивает:',
#  '- Папа, тебе понравился мой  жених?',
#  '- Он, конечно, полный ноль, но  приятно, что меня боженькой называет…',
#  '',
#  'Адам спрашивает у Бога:',
#  '- Господи, почему ты сделал  Еву такой красивой?',
#  '- Чтобы она тебе понравилась,  сын мой.',
#  '- Боже, но почему же ты сделал  ее такой глупой?',
#  '- А это, чтобы ты ей  понравился…',
#  '',
#  'Приехали в Новую Зеландию три  приятеля – биолог, физик и математик. Едут на машине. Видят, на зеленом  лугу пасется черная овца.',
#  'Биолог: Это говорит о том, что  здесь водятся черные овцы.',
#  'Физик: Это говорит о том, что  здесь водится по крайней мере одна черная овца.',
#  'Математик: Это говорит о том,  здесь водится по крайней мере одна овца, черная по крайней мере с одной  стороны.',
#  '',
#  'Пошли муж и жена на охоту. Он  дал ей ружье.',
#  '- Я на тебя из леса выгоню  лося, и ты тогда стреляй.',
#  'Ушел в лес. Вдруг слышит  выстрелы, шум, крики. Подбегает, а там его жена и какой-то мужик. Жена  наставила на него ружье и кричит:',
#  '- Это мой лось! Отойди!',
#  '- Ладно-ладно, твой. Можно, я  только седло сниму?',
#  '',
#  'Подходит\xa0 школе  к Вовочке девочка:',
#  '- Вовочка, у вас дома ТАКОЕ!',
#  'Потом подошел и директор  школы:',
#  '- Вовочка, иди домой, у вас  дома ТАКОЕ!',
#  'На улице знакомые тоже  говорили:',
#  '- Вовочка, у вас дома ТАКОЕ!',
#  'Прибежал он домой. И ему  говорят:',
#  '- Вовочка, у нас ТАКОЕ! Твой  брат Саша бомбу в царя бросил…',
#  '',
#  'Немец в Лондоне заходит в паб:',
#  '- Two Martini,  please.',
#  '- Dry?',
#  '- Nein, nur zwei!',
#  '',
#  'В зоопарке  медведь жалуется директору:',
#  '- Переведите меня в другую  клетку, я так больше жить не могу! У меня справа обезьяна, а слева  жираф. Обезьяна весь день анекдоты рассказывает, а жираф всю ночь  смеется.',
#  '',
#  'Два электрика в подъезде  что-то чинят и спорят. Идет бабушка.',
#  '- Бабушка! Подержи провод.',
#  '- Ну, вот, я же тебе говорил,  что это ноль, а ты «фаза-фаза»…',
#  '',
#  '- Правильно говорят, что  блондинки глупые! Моя жена была брюнеткой, вчера днем перекрасилась в  блондинку, а вечером устроила скандал, когда нашла в постели черные  волосы.',
#  '',
#  'Собака думает: Человек обо мне  заботится, кормит меня, поит, дает кров. Наверное, он Бог!',
#  'Кошка думает: Человек обо мне  заботится, кормит меня, поит, дает кров. Наверное, я Бог!',
#  '',
#  'Человек думает: Собака очень  сообразительно существо. За кусочек лакомства быстро приучается  выполнять несложные трюки.',
#  'Собака думает: Человек очень  сообразительное существо. За несложные трюки быстро приучается давать  лакомство.',
#  '',
#  'Чебурашка рассматривает себя в  зеркало.',
#  '- Может быть, мне жениться?  Или замуж выйти…',
#  '',
#  'Чем отличается мужское  общежитие от женского? В женском общежитии посуду моют после еды, а в  мужском – перед едой.',
#  '',
#  'Маленькие мальчик и девочка  играют в песочнице.',
#  '- У меня есть совочек.',
#  '- А у меня ведерко.',
#  '- У меня мячик.',
#  '- А у меня скакалка.',
#  '- У меня машинка.',
#  '- А у меня кукла.',
#  'Когда игрушек уже не осталось,  мальчик снял штанишки:',
#  '- А у меня вот что есть!',
#  'Девочке ответить было нечем,  она заплакала и убежала домой. Через какое-то время возвращается  спокойная и гордая:',
#  '- А мне мама сказала, что,  когда я вырасту, у меня таких будет, сколько захочу!',
#  '',
#  'На приеме у психотерапевта:',
#  '- Доктор, меня все игнорируют.',
#  '- Следующий!',
#  '',
#  'Зайчик и белочка пришли к  мудрой сове:',
#  '- Мудрая сова, вот мы любим  друг друга, живем вместе, а у нас почему-то нет детишек. Это потому что  мы зайчик и белочка?',
#  '- Нет! Это потому что вы  мальчик и мальчик.',
#  '',
#  'Рабинович каждый день ходит в  синагогу и молится:',
#  '- Господи, помоги мне выиграть  в лотерею. Ну, пожалуйста, помоги мне выиграть в лотерею.',
#  'Это продолжается несколько  месяцев. Во время очередной молитвы откуда-то сверху вдруг раздается  божественный голос:',
#  '- Рабинович, купи хотя бы один  лотерейный билет!']

# %%
# Альтернативный способ поиска элементов:
elements = soup.find_all('p')

# Посмотрим на первый элемент
elements[3]
# Out:
# <p>- Почему так много?</p>

# %%
# Выделяем из одного элемента всю информацию по отдельности, и преобразуем её в объект:
elements = soup.find_all('p')
data = []

for e in elements:
    data.append({
        'title': e.text.strip().split('\n')[0],
        
    })
    
data
# Out:
# [{'title': 'Нет товаров'},
#  {'title': 'Продолжить покупки'},
#  {'title': 'В  Москве проходит тендер на строительство здания. Проект представляет  немецкая компания. Смета 10 миллионов. Затем турецкая компания – 5  миллионов. Подходит черед российской компании. У них смета 15 миллионов.'},
#  {'title': '- Почему так много?'},
#  {'title': '- Ну, как же? 5 миллионов нам,  5 миллионов вам и 5 туркам, чтобы строили.'},
#  {'title': 'И они выигрывают тендер!'},
#  {'title': ''},
#  {'title': 'Один бизнесмен хотел жениться,  но у него было три подружки, и он не знал какую из них выбрать. Решил  их проверить: дал каждой по 1000 долларов. Одна потратила все деньги на  себя, другая купила что-то для хозяйства, а третья вложила в дело и  получила прибыль. Какую же из трех он выбрал? Ту, у которой грудь  больше!'},
#  {'title': ''},
#  {'title': 'Едет русский на своем  автомобиле по Украине. Его останавливает украинский гаишник:'},
#  {'title': '- Вы нарушили правила, пишите  объяснительную записку на украинском языке.'},
#  {'title': '- Но я не умею, на  украинском!..'},
#  {'title': '- Тогда отберем права.'},
#  {'title': 'Что делать? Русский положил в  чистый лист 100 долларов. Гаишник смотрит.'},
#  {'title': '-Ну, вот, говорите, что не  умеете, а половину уже написали!'},
#  {'title': ''},
#  {'title': 'Поздний вечер. Мужа нет дома.  Жена волнуется.'},
#  {'title': '- Наверное, он с другой  женщиной, я давно подозревала…'},
#  {'title': 'Теща:'},
#  {'title': '- Зачем ты думаешь сразу о  плохом? Может быть, он просто попал под машину…'},
#  {'title': ''},
#  {'title': 'Женщины бывают или «прелесть,  какие глупенькие», или «ужас, какие дуры!»'},
#  {'title': ''},
#  {'title': 'Урок в кавказской школе. Учитель  вызвал ученика и попросил начертить равнобедренный треугольник. Мальчик  начертил. Учитель:'},
#  {'title': '- А теперь докажи, что он  равнобедренный.'},
#  {'title': '- Мамой клянусь, равнобедренный!'},
#  {'title': ''},
#  {'title': 'Объявлен  международный тендер на прокладку трубопровода по дну океана из Европы в  Америку. Проект представляет немецкая компания, показывает графики,  схемы, сметы.'},
#  {'title': '- Мы будем  работать три года. Начнем с двух сторон. Когда дойдем до середины,  гарантируем, что расхождение будет не более десяти метров.'},
#  {'title': 'Японская  компания, показывает проект:'},
#  {'title': '- Мы будем  работать два года. Начнем с двух сторон. Когда дойдем до середины,  гарантируем, что расхождение будет не более пяти метров.'},
#  {'title': 'Русская  компания:'},
#  {'title': '- Мы будем  работать полгода. Начнем с двух сторон. Ничего не гарантируем. В крайнем  случае, будет две трубы.'},
#  {'title': ''},
#  {'title': 'Солдат  спрашивает у прапорщика:'},
#  {'title': '- Товарищ  прапорщик, а крокодилы летают?'},
#  {'title': '- Конечно,  нет! Ерунда какая!'},
#  {'title': '- Да?.. А  товарищ лейтенант сказал, что летают…'},
#  {'title': '- Ну, они  летают, но только низенько-низенько.'},
#  {'title': '- А товарищ  лейтенант сказал, что высоко.'},
#  {'title': '- Они  сначала низенько-низенько, а потом как взмоют!'},
#  {'title': ''},
#  {'title': 'Разговаривают  два солдатика.'},
#  {'title': '- Слушай,  давай над лейтенантом приколемся.'},
#  {'title': '- Ага, над деканом уже  прикололись…'},
#  {'title': ''},
#  {'title': 'Штирлиц  проснулся в камере. Как сюда попал, не помнит. Думает: «Если войдут  русские, скажу, что я полковник Исаев. Если немцы – штандартенфюрер  Штирлиц».'},
#  {'title': 'Входит  милиционер:'},
#  {'title': '-Ну, и  напились Вы вчера, товарищ Тихонов!'},
#  {'title': ''},
#  {'title': 'Москвичей  нигде не любят, особенно в Москве…'},
#  {'title': ''},
#  {'title': 'Белорусские  новости: «Александр Григорьевич Лукашенко заявил, что он не хочет больше  быть президентом. Коронация назначена на вторник».'},
#  {'title': ''},
#  {'title': 'У одного  мужика была бахча, но кто-то повадился таскать с нее арбузы. Чтобы это  прекратить, он поставил табличку «Внимание! Один из арбузов отравлен».  На следующий день видит, на табличке подписано: «Теперь их два…»'},
#  {'title': ''},
#  {'title': 'Китаец был в  Москве. Когда вернулся домой, родственники его спрашивают:'},
#  {'title': '-Ну, как  тебе Москва?'},
#  {'title': '-Хороший  город, чистый и народу мало!'},
#  {'title': ''},
#  {'title': 'Богатый  студент пришел на экзамен, но не подготовился. Положил в чистую тетрадь  пять тысяч долларов и написал: «Профессор, по штуке за балл». Когда ему  вернули тетрадь с результатами, там лежало три тысячи и рукой профессора  написано: «Сдача».'},
#  {'title': ''},
#  {'title': 'Из ПДД для  блондинок: «Действие знака «Обгон запрещен» распространяется не только  на автомобили красного цвета».'},
#  {'title': ''},
#  {'title': 'Один  строитель всю жизнь строил мосты, а когда ушел на пенсию, его дело  продолжил сын. Однажды сын пришел к отцу и с гордостью говорит:'},
#  {'title': '-  Папа, я достроил мост, который ты строил тридцать лет!'},
#  {'title': '-  Сынок, пока строился этот мост, я тебя вырастил и выучил. А ты как  будешь кормить свою семью?'},
#  {'title': ''},
#  {'title': 'Разговор  двух приятелей:'},
#  {'title': '- Я  свою жену называю «зайка», «рыбка», «птичка»…'},
#  {'title': '-  Ну, а она что?'},
#  {'title': '-  Уши развесит, глаза выпучит и клювом щелкает!'},
#  {'title': ''},
#  {'title': 'Что такое рай? Это английский  дом, китайская кухня, американская зарплата и русская жена.'},
#  {'title': 'А что такое ад? Это китайский  дом, английская кухня, русская зарплата и американская жена.'},
#  {'title': ''},
#  {'title': 'Если  мужчине сказать: «Ты такой же дурак, как Вася!» Он спросит, почему это  он дурак?'},
#  {'title': 'Если  женщине сказать: «Ты такая же дура, как Маша!» Она возмутится: Почему  это я, как Маша?!»'},
#  {'title': ''},
#  {'title': 'МУЖСКОЙ РЕЦЕПТ  ШАРЛОТКИ (простого яблочного пирога).'},
#  {'title': 'Возьмите  из холодильника 10 яиц, положите на стол оставшиеся семь и вытрите пол.  Возьмите большую миску и разбейте об ее край яйца. Вылейте их  содержимое в миску. Протрите стол. Итак, у вас в миске 5 яиц. Теперь  возьмите миксер, вставьте венчики и начните взбивать. Попробуйте еще раз  вставить венчики, теперь до щелчка. Взбивайте. Вымойте лицо, шею, руки,  спину, уши. В итоге у вас в миске осталось два взбитых яйца. Обклейте  стены и потолок кухни газетой, накройте мебель какой-нибудь тканью –  пора доставать муку… Насыпьте 200 г в стакан, затем высыпьте в миску.  Оставшиеся 800 г аккуратно соберите обратно в пакет. Взбивайте. Примите  душ. Возьмите 4 больших яблока и нож. Приготовьте йод, пластырь и бинт.  Очистите яблоки. Обработайте большой палец йодом и забинтуйте его.  Нарежьте яблоки кубиками и помните, вам понадобится 2 яблока, так что в  процессе готовки можно съесть только половину. Обработайте йодом  указательный и средний пальцы. Единственное оставшееся и уже нарезанное  яблоко сбросьте в миску, подберите с пола упавшие кусочки, помойте их и  тоже положите в миску. Взбивайте все миксером. Отмойте холодильник.  Теперь выливайте содержимое в сковородку и ставьте в духовку. Подождите  час и, не увидев ощутимых изменений, включите духовку. Проснувшись, не  звоните в Службу спасения, а просто выключите духовку и откройте окна...'},
#  {'title': ''},
#  {'title': 'Объявление в  газете: «Потомственный алкоголик в четвертом поколении быстро и  безболезненно снимет любую кодировку».'},
#  {'title': ''},
#  {'title': 'Разговор двух подростков:'},
#  {'title': '- Мне отец привез из Африки  большого попугая за тысячу долларов!'},
#  {'title': '- Красивый попугай?'},
#  {'title': '- Красивый!'},
#  {'title': '- Говорящий?'},
#  {'title': '- Говорящий!'},
#  {'title': '- Вкусный?'},
#  {'title': '- Ты что?! Попугай штуку  баксов стоит. Конечно, вкусный!'},
#  {'title': ''},
#  {'title': '- Сынок, с 23-им февраля!'},
#  {'title': '- Пап, не каркай, может, я еще  поступлю…'},
#  {'title': ''},
#  {'title': '- У меня на даче дом-на.'},
#  {'title': '- Зачем тебе?'},
#  {'title': '- Я там живу-на!'},
#  {'title': ''},
#  {'title': '- Будет ли Третья мировая  ойна?'},
#  {'title': '- Будет.'},
#  {'title': '- А сколько после войны будет  стоить в Америке банка «Кока-колы»?'},
#  {'title': '- Один рубль.'},
#  {'title': ''},
#  {'title': 'Студент духовной семинарии  полюбил дочку олигарха. Он решили пожениться. Пришел жених поговорить с  отцом невесты.'},
#  {'title': '- А Вы знаете, что моя дочь  привыкла ни в чем себе не отказывать? Она шубы и драгоценности через  день покупает. Вы сможете ей это обеспечить?'},
#  {'title': '- Боженька поможет!'},
#  {'title': '- А еще она дорогие машины  меняет по нескольку раз в год.'},
#  {'title': '- Боженька поможет!'},
#  {'title': '- Она еще часто за границу  ездит, на отдых, на шопинг…'},
#  {'title': '- Боженька поможет!'},
#  {'title': 'Позже дочка спрашивает:'},
#  {'title': '- Папа, тебе понравился мой  жених?'},
#  {'title': '- Он, конечно, полный ноль, но  приятно, что меня боженькой называет…'},
#  {'title': ''},
#  {'title': 'Адам спрашивает у Бога:'},
#  {'title': '- Господи, почему ты сделал  Еву такой красивой?'},
#  {'title': '- Чтобы она тебе понравилась,  сын мой.'},
#  {'title': '- Боже, но почему же ты сделал  ее такой глупой?'},
#  {'title': '- А это, чтобы ты ей  понравился…'},
#  {'title': ''},
#  {'title': 'Приехали в Новую Зеландию три  приятеля – биолог, физик и математик. Едут на машине. Видят, на зеленом  лугу пасется черная овца.'},
#  {'title': 'Биолог: Это говорит о том, что  здесь водятся черные овцы.'},
#  {'title': 'Физик: Это говорит о том, что  здесь водится по крайней мере одна черная овца.'},
#  {'title': 'Математик: Это говорит о том,  здесь водится по крайней мере одна овца, черная по крайней мере с одной  стороны.'},
#  {'title': ''},
#  {'title': 'Пошли муж и жена на охоту. Он  дал ей ружье.'},
#  {'title': '- Я на тебя из леса выгоню  лося, и ты тогда стреляй.'},
#  {'title': 'Ушел в лес. Вдруг слышит  выстрелы, шум, крики. Подбегает, а там его жена и какой-то мужик. Жена  наставила на него ружье и кричит:'},
#  {'title': '- Это мой лось! Отойди!'},
#  {'title': '- Ладно-ладно, твой. Можно, я  только седло сниму?'},
#  {'title': ''},
#  {'title': 'Подходит\xa0 школе  к Вовочке девочка:'},
#  {'title': '- Вовочка, у вас дома ТАКОЕ!'},
#  {'title': 'Потом подошел и директор  школы:'},
#  {'title': '- Вовочка, иди домой, у вас  дома ТАКОЕ!'},
#  {'title': 'На улице знакомые тоже  говорили:'},
#  {'title': '- Вовочка, у вас дома ТАКОЕ!'},
#  {'title': 'Прибежал он домой. И ему  говорят:'},
#  {'title': '- Вовочка, у нас ТАКОЕ! Твой  брат Саша бомбу в царя бросил…'},
#  {'title': ''},
#  {'title': 'Немец в Лондоне заходит в паб:'},
#  {'title': '- Two Martini,  please.'},
#  {'title': '- Dry?'},
#  {'title': '- Nein, nur zwei!'},
#  {'title': ''},
#  {'title': 'В зоопарке  медведь жалуется директору:'},
#  {'title': '- Переведите меня в другую  клетку, я так больше жить не могу! У меня справа обезьяна, а слева  жираф. Обезьяна весь день анекдоты рассказывает, а жираф всю ночь  смеется.'},
#  {'title': ''},
#  {'title': 'Два электрика в подъезде  что-то чинят и спорят. Идет бабушка.'},
#  {'title': '- Бабушка! Подержи провод.'},
#  {'title': '- Ну, вот, я же тебе говорил,  что это ноль, а ты «фаза-фаза»…'},
#  {'title': ''},
#  {'title': '- Правильно говорят, что  блондинки глупые! Моя жена была брюнеткой, вчера днем перекрасилась в  блондинку, а вечером устроила скандал, когда нашла в постели черные  волосы.'},
#  {'title': ''},
#  {'title': 'Собака думает: Человек обо мне  заботится, кормит меня, поит, дает кров. Наверное, он Бог!'},
#  {'title': 'Кошка думает: Человек обо мне  заботится, кормит меня, поит, дает кров. Наверное, я Бог!'},
#  {'title': ''},
#  {'title': 'Человек думает: Собака очень  сообразительно существо. За кусочек лакомства быстро приучается  выполнять несложные трюки.'},
#  {'title': 'Собака думает: Человек очень  сообразительное существо. За несложные трюки быстро приучается давать  лакомство.'},
#  {'title': ''},
#  {'title': 'Чебурашка рассматривает себя в  зеркало.'},
#  {'title': '- Может быть, мне жениться?  Или замуж выйти…'},
#  {'title': ''},
#  {'title': 'Чем отличается мужское  общежитие от женского? В женском общежитии посуду моют после еды, а в  мужском – перед едой.'},
#  {'title': ''},
#  {'title': 'Маленькие мальчик и девочка  играют в песочнице.'},
#  {'title': '- У меня есть совочек.'},
#  {'title': '- А у меня ведерко.'},
#  {'title': '- У меня мячик.'},
#  {'title': '- А у меня скакалка.'},
#  {'title': '- У меня машинка.'},
#  {'title': '- А у меня кукла.'},
#  {'title': 'Когда игрушек уже не осталось,  мальчик снял штанишки:'},
#  {'title': '- А у меня вот что есть!'},
#  {'title': 'Девочке ответить было нечем,  она заплакала и убежала домой. Через какое-то время возвращается  спокойная и гордая:'},
#  {'title': '- А мне мама сказала, что,  когда я вырасту, у меня таких будет, сколько захочу!'},
#  {'title': ''},
#  {'title': 'На приеме у психотерапевта:'},
#  {'title': '- Доктор, меня все игнорируют.'},
#  {'title': '- Следующий!'},
#  {'title': ''},
#  {'title': 'Зайчик и белочка пришли к  мудрой сове:'},
#  {'title': '- Мудрая сова, вот мы любим  друг друга, живем вместе, а у нас почему-то нет детишек. Это потому что  мы зайчик и белочка?'},
#  {'title': '- Нет! Это потому что вы  мальчик и мальчик.'},
#  {'title': ''},
#  {'title': 'Рабинович каждый день ходит в  синагогу и молится:'},
#  {'title': '- Господи, помоги мне выиграть  в лотерею. Ну, пожалуйста, помоги мне выиграть в лотерею.'},
#  {'title': 'Это продолжается несколько  месяцев. Во время очередной молитвы откуда-то сверху вдруг раздается  божественный голос:'},
#  {'title': '- Рабинович, купи хотя бы один  лотерейный билет!'}]

# %%
# Подключаем Pandas и преобразуем объект в датафрейм:
df = pd.DataFrame(data)
df

# Мы распарсили одну страничку каталога !!!!!!!!
# Out:
#                                                  title
# 0                                          Нет товаров
# 1                                   Продолжить покупки
# 2    В  Москве проходит тендер на строительство зда...
# 3                                  - Почему так много?
# 4    - Ну, как же? 5 миллионов нам,  5 миллионов ва...
# ..                                                 ...
# 186
# 187  Рабинович каждый день ходит в  синагогу и моли...
# 188  - Господи, помоги мне выиграть  в лотерею. Ну,...
# 189  Это продолжается несколько  месяцев. Во время ...
# 190  - Рабинович, купи хотя бы один  лотерейный билет!
#
# [191 rows x 1 columns]

# %%
# Определяем максимальный номер страницы каталога
soup.find('div', class_='uss_page_num')
# Out:
# <div class="uss_page_num">
# <span class="uss_10_pages_bac"><a href="https://salonak.ru/katalog-tovarov/?page=1" title="На 10 страниц назад">&lt;&lt;</a></span>
# <span class="uss_page uss_page_selected"><a href="https://salonak.ru/katalog-tovarov/" title="На страницу 1">1</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=2" title="На страницу 2">2</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=3" title="На страницу 3">3</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=4" title="На страницу 4">4</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=5" title="На страницу 5">5</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=6" title="На страницу 6">6</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=7" title="На страницу 7">7</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=8" title="На страницу 8">8</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=9" title="На страницу 9">9</a></span>
# <span class="uss_page_forward">..</span>
# <span class="uss_page_forward"><a href="https://salonak.ru/katalog-tovarov/?page=54" title="Последняя страница">54</a></span>
# <span class="uss_10_pages_forward"><a href="https://salonak.ru/katalog-tovarov/?page=11" title="На 10 страниц вперед">&gt;&gt;</a></span>
# </div>

# %%
# 1. Определяем див с нумерацией страниц;
# 2. Определяем внутри этого DIVа блоки с цифрами;
# 3. Выделяем текст TEXT внутри, удаляем лишние символы с помощью STRIP и преобразуем цифры из строкового в целочисленный формат INT
pagination = soup.find('div', class_='uss_page_num')
pages = [int(p.text.strip()) for p in pagination.find_all('span', class_='uss_page')]
pages
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# Определяем максимальный номер на текущей странице
max_page = max(pages)
max_page
# Out:
# 9

# %%
# Pandas
import pandas as pd
import numpy as np
import sys
from datetime import datetime

# Подключаем библиотеку для парсинга сайтов !!!!!!!!!!!!!
import requests

# Подключаем библиотеку для поиска элементов кода на сайте !!!!!!!!!!!!!
from bs4 import BeautifulSoup

# Подключаем библиотеку для соединения с google-таблицами !!!!!!!!!!!!!
import gspread

# %%
# Для определения текущей даты и времени
ts_now = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
ts_now
# Out:
# '2024-09-20 20:52:26'

# %%
# А ТЕПЕРЬ СНОВА ПОПРОБУЕМ распарсить все страницы каталога:
# Отправка запроса на сайт для получения кода:

data = []
page = 1
max_page = 1

while page <= max_page:
    res = requests.get(f'https://salonak.ru/katalog-tovarov/?page={page}')
    soup = BeautifulSoup(res.text, 'html')

    elements = soup.find_all('div', class_='uss_eshop_item order_one buyclick_available')

    for e in elements:
        data.append({
            'title': e.text.strip().split('\n')[0],
            'price': e.text.strip().split('\n')[3].replace(' руб.',''),
        })
    
#     print(data)
# Усложняем код из-за появления в нумерации страниц знаков "..."        
        
    pagination = soup.find('div', class_='uss_page_num') # ('span', class_='uss_page')
#     print(pagination)
#     pagination = soup.find('nav', class_='woocommerce-pagination')
#     pages = [int(p) for p in pagination.text.strip()]
#     pages = [int(p.text.strip()) for p in pagination.find_all('div', class_='uss_page_num')]
    pages = [int(p.text.strip()) for p in pagination.find_all('span', class_='uss_page')]
#     print(pages)
#     int_pages = []
    
#     for p in pages:
#         try:
#             n = int(p)
#             int_pages.append(n)
#         except:
#             continue
            
#     print(int_pages)
    max_page = max(pages)
    page += 1
#     print(page, max_page)

#     df = pd.DataFrame(data)
#     df

# %%
df = pd.DataFrame(data)
df['timestamp'] = ts_now
df.head()
# Out:
#                                                title price  \
# 0  Стимулирующее масло для бороды и усов MEN’S MA...   711
# 1  Шампунь Окрашивающий для волос MEN’S MASTER Чё...   106
# 2  Шампунь окрашивающий для волос MEN’S MASTER Ко...   106
# 3  Шампунь Стимулирующий "Красный перец, кофеин и...   765
# 4  Шампунь Детокс "Уголь и репей" MEN’S MASTER 26...   816
#
#              timestamp
# 0  2024-09-20 20:52:26
# 1  2024-09-20 20:52:26
# 2  2024-09-20 20:52:26
# 3  2024-09-20 20:52:26
# 4  2024-09-20 20:52:26

# %%
# УСТАНОВКА БИБЛИОТЕКИ ДЛЯ ЗАПИСИ ДАННЫХ В GOOGLE-ТАБЛИЦУ
# GSPREAD

# %%
# Установка библиотеки !!!!!!!!!!!!!
# !pip install gspread
# Out:
# Collecting gspread
#   Downloading gspread-6.1.2-py3-none-any.whl (57 kB)
# Collecting google-auth-oauthlib>=0.4.1
#   Downloading google_auth_oauthlib-1.2.1-py2.py3-none-any.whl (24 kB)
# Collecting google-auth>=1.12.0
#   Downloading google_auth-2.35.0-py2.py3-none-any.whl (208 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.24.0)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting pyasn1<0.7.0,>=0.4.6
#   Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.10)
# Installing collected packages: pyasn1, pyasn1-modules, rsa, cachetools, google-auth, oauthlib, requests-oauthlib, google-auth-oauthlib, gspread
# Successfully installed cachetools-5.5.0 google-auth-2.35.0 google-auth-oauthlib-1.2.1 gspread-6.1.2 oauthlib-3.2.2 pyasn1-0.6.1 pyasn1-modules-0.4.1 requests-oauthlib-2.0.0 rsa-4.9

# %%
# Подключаем библиотеку !!!!!!!!!!!!!
import gspread

# %%
# Quick Example
import gspread

# Объявляем ключ для связи с сервисным аккаунтом и его расположение на диске
gc = gspread.service_account(filename='beauty-salon-key.json')

# Open a sheet from a spreadsheet in one go
wks = gc.open("web_parsing_report").sheet1

# Update a range of cells using the top left corner address
wks.update([[1, 2], [3, 4]], 'A1')

# Or update a single cell
wks.update_acell('B42', "it's down there somewhere, let me take another look.")

# Format the header
wks.format('A1:B1', {'textFormat': {'bold': True}})
# Out:
# {'spreadsheetId': '1XQBizX0YVDsZ7PaHlNvnEVLwyOxUZuFJo0447ku6Qdg',
#  'replies': [{}]}

# %%
# Using gspread with pandas

# %%
# EN
# pandas is a popular library for data analysis.
# The simplest way to get data from a sheet to a pandas DataFrame is with get_all_records():
# RU
# pandas — популярная библиотека для анализа данных.
# Самый простой способ получить данные из таблицы в pandas DataFrame — это get_all_records():
# import pandas as pd

dataframe = pd.DataFrame(worksheet.get_all_records())

# %%
# EN
# Here’s a basic example for writing a dataframe to a sheet.
# With update() we put the header of a dataframe into the first row of a sheet followed by the values of a dataframe:
# RU
# Вот простой пример записи dataframe на лист.
# С помощью update() мы помещаем заголовок dataframe в первую строку листа, за которым следуют значения dataframe:
# import pandas as pd

worksheet.update([dataframe.columns.values.tolist()] + dataframe.values.tolist())

# %%
# Изменяем код для вставки в Google наших запарсенных данных
# Объявляем ключ для связи с сервисным аккаунтом и его расположение на диске
gc = gspread.service_account(filename='beauty-salon-key.json')

# Open a sheet from a spreadsheet in one go
wks = gc.open("web_parsing_report").sheet1

# Getting All Values From a Worksheet as a List of Dictionaries
# Получение всех значений из рабочего листа в виде списка словарей
current_df = pd.DataFrame(wks.get_all_records())

# Update a range of cells using the top left corner address
# wks.update([[1, 2], [3, 4]], 'A1')
wks.update([df.columns.values.tolist()] + df.values.tolist())
# Out:
# {'spreadsheetId': '1XQBizX0YVDsZ7PaHlNvnEVLwyOxUZuFJo0447ku6Qdg',
#  'updatedRange': "'Лист1'!A1:C2156",
#  'updatedRows': 2156,
#  'updatedColumns': 3,
#  'updatedCells': 6468}

# %%
# Для добавления новых данных в таблицу (а не перезапись)

merged_df = pd.concat([df, current_df])
merged_df.shape
wks.update([merged_df.columns.values.tolist()] + merged_df.values.tolist())
# Out:
# {'spreadsheetId': '1XQBizX0YVDsZ7PaHlNvnEVLwyOxUZuFJo0447ku6Qdg',
#  'updatedRange': "'Лист1'!A1:C4311",
#  'updatedRows': 4311,
#  'updatedColumns': 3,
#  'updatedCells': 12933}
